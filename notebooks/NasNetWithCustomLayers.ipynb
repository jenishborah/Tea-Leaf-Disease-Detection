# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

# %%
data_dir='D:\\Msc GU\\Msc 4th Sem\\Project\\DataSet\\teadataset'

# %%
# Set up data augmentation
datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2)

# Load in the dataset
train_data = datagen.flow_from_directory(
    data_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='training')

val_data = datagen.flow_from_directory(
    data_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='validation')
# Out:
# Found 711 images belonging to 8 classes.
# Found 174 images belonging to 8 classes.

# %%
base_model = tf.keras.applications.NASNetMobile(
    input_shape=(224, 224, 3),
    include_top=False)

# Freeze all but the last few layers of the base model
for layer in base_model.layers[:-10]:
    layer.trainable = False

# Add some layers on top of the pre-trained model
x = base_model.output
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dense(512, activation='relu')(x)
x = tf.keras.layers.Dropout(0.5)(x)
x = tf.keras.layers.Dense(8, activation='softmax')(x)
# Create the final model
model = tf.keras.models.Model(inputs=base_model.input, outputs=x)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  stem_conv1 (Conv2D)            (None, 111, 111, 32  864         ['input_2[0][0]']
#                                 )
#
#  stem_bn1 (BatchNormalization)  (None, 111, 111, 32  128         ['stem_conv1[0][0]']
#                                 )
#
#  activation_188 (Activation)    (None, 111, 111, 32  0           ['stem_bn1[0][0]']
#                                 )
#
#  reduction_conv_1_stem_1 (Conv2  (None, 111, 111, 11  352        ['activation_188[0][0]']
#  D)                             )
#
#  reduction_bn_1_stem_1 (BatchNo  (None, 111, 111, 11  44         ['reduction_conv_1_stem_1[0][0]']
#  rmalization)                   )
#
#  activation_189 (Activation)    (None, 111, 111, 11  0           ['reduction_bn_1_stem_1[0][0]']
#                                 )
#
#  activation_191 (Activation)    (None, 111, 111, 32  0           ['stem_bn1[0][0]']
#                                 )
#
#  separable_conv_1_pad_reduction  (None, 115, 115, 11  0          ['activation_189[0][0]']
#  _left1_stem_1 (ZeroPadding2D)  )
#
#  separable_conv_1_pad_reduction  (None, 117, 117, 32  0          ['activation_191[0][0]']
#  _right1_stem_1 (ZeroPadding2D)  )
#
#  separable_conv_1_reduction_lef  (None, 56, 56, 11)  396         ['separable_conv_1_pad_reduction_
#  t1_stem_1 (SeparableConv2D)                                     left1_stem_1[0][0]']
#
#  separable_conv_1_reduction_rig  (None, 56, 56, 11)  1920        ['separable_conv_1_pad_reduction_
#  ht1_stem_1 (SeparableConv2D)                                    right1_stem_1[0][0]']
#
#  separable_conv_1_bn_reduction_  (None, 56, 56, 11)  44          ['separable_conv_1_reduction_left
#  left1_stem_1 (BatchNormalizati                                  1_stem_1[0][0]']
#  on)
#
#  separable_conv_1_bn_reduction_  (None, 56, 56, 11)  44          ['separable_conv_1_reduction_righ
#  right1_stem_1 (BatchNormalizat                                  t1_stem_1[0][0]']
#  ion)
#
#  activation_190 (Activation)    (None, 56, 56, 11)   0           ['separable_conv_1_bn_reduction_l
#                                                                  eft1_stem_1[0][0]']
#
#  activation_192 (Activation)    (None, 56, 56, 11)   0           ['separable_conv_1_bn_reduction_r
#                                                                  ight1_stem_1[0][0]']
#
#  separable_conv_2_reduction_lef  (None, 56, 56, 11)  396         ['activation_190[0][0]']
#  t1_stem_1 (SeparableConv2D)
#
#  separable_conv_2_reduction_rig  (None, 56, 56, 11)  660         ['activation_192[0][0]']
#  ht1_stem_1 (SeparableConv2D)
#
#  activation_193 (Activation)    (None, 111, 111, 32  0           ['stem_bn1[0][0]']
#                                 )
#
#  separable_conv_2_bn_reduction_  (None, 56, 56, 11)  44          ['separable_conv_2_reduction_left
#  left1_stem_1 (BatchNormalizati                                  1_stem_1[0][0]']
#  on)
#
#  separable_conv_2_bn_reduction_  (None, 56, 56, 11)  44          ['separable_conv_2_reduction_righ
#  right1_stem_1 (BatchNormalizat                                  t1_stem_1[0][0]']
#  ion)
#
#  separable_conv_1_pad_reduction  (None, 117, 117, 32  0          ['activation_193[0][0]']
#  _right2_stem_1 (ZeroPadding2D)  )
#
#  activation_195 (Activation)    (None, 111, 111, 32  0           ['stem_bn1[0][0]']
#                                 )
#
#  reduction_add_1_stem_1 (Add)   (None, 56, 56, 11)   0           ['separable_conv_2_bn_reduction_l
#                                                                  eft1_stem_1[0][0]',
#                                                                   'separable_conv_2_bn_reduction_r
#                                                                  ight1_stem_1[0][0]']
#
#  separable_conv_1_reduction_rig  (None, 56, 56, 11)  1920        ['separable_conv_1_pad_reduction_
#  ht2_stem_1 (SeparableConv2D)                                    right2_stem_1[0][0]']
#
#  separable_conv_1_pad_reduction  (None, 115, 115, 32  0          ['activation_195[0][0]']
#  _right3_stem_1 (ZeroPadding2D)  )
#
#  activation_197 (Activation)    (None, 56, 56, 11)   0           ['reduction_add_1_stem_1[0][0]']
#
#  separable_conv_1_bn_reduction_  (None, 56, 56, 11)  44          ['separable_conv_1_reduction_righ
#  right2_stem_1 (BatchNormalizat                                  t2_stem_1[0][0]']
#  ion)
#
#  separable_conv_1_reduction_rig  (None, 56, 56, 11)  1152        ['separable_conv_1_pad_reduction_
#  ht3_stem_1 (SeparableConv2D)                                    right3_stem_1[0][0]']
#
#  separable_conv_1_reduction_lef  (None, 56, 56, 11)  220         ['activation_197[0][0]']
#  t4_stem_1 (SeparableConv2D)
#
#  activation_194 (Activation)    (None, 56, 56, 11)   0           ['separable_conv_1_bn_reduction_r
#                                                                  ight2_stem_1[0][0]']
#
#  separable_conv_1_bn_reduction_  (None, 56, 56, 11)  44          ['separable_conv_1_reduction_righ
#  right3_stem_1 (BatchNormalizat                                  t3_stem_1[0][0]']
#  ion)
#
#  separable_conv_1_bn_reduction_  (None, 56, 56, 11)  44          ['separable_conv_1_reduction_left
#  left4_stem_1 (BatchNormalizati                                  4_stem_1[0][0]']
#  on)
#
#  reduction_pad_1_stem_1 (ZeroPa  (None, 113, 113, 11  0          ['reduction_bn_1_stem_1[0][0]']
#  dding2D)                       )
#
#  separable_conv_2_reduction_rig  (None, 56, 56, 11)  660         ['activation_194[0][0]']
#  ht2_stem_1 (SeparableConv2D)
#
#  activation_196 (Activation)    (None, 56, 56, 11)   0           ['separable_conv_1_bn_reduction_r
#                                                                  ight3_stem_1[0][0]']
#
#  activation_198 (Activation)    (None, 56, 56, 11)   0           ['separable_conv_1_bn_reduction_l
#                                                                  eft4_stem_1[0][0]']
#
#  reduction_left2_stem_1 (MaxPoo  (None, 56, 56, 11)  0           ['reduction_pad_1_stem_1[0][0]']
#  ling2D)
#
#  separable_conv_2_bn_reduction_  (None, 56, 56, 11)  44          ['separable_conv_2_reduction_righ
#  right2_stem_1 (BatchNormalizat                                  t2_stem_1[0][0]']
#  ion)
#
#  separable_conv_2_reduction_rig  (None, 56, 56, 11)  396         ['activation_196[0][0]']
#  ht3_stem_1 (SeparableConv2D)
#
#  separable_conv_2_reduction_lef  (None, 56, 56, 11)  220         ['activation_198[0][0]']
#  t4_stem_1 (SeparableConv2D)
#
#  adjust_relu_1_stem_2 (Activati  (None, 111, 111, 32  0          ['stem_bn1[0][0]']
#  on)                            )
#
#  reduction_add_2_stem_1 (Add)   (None, 56, 56, 11)   0           ['reduction_left2_stem_1[0][0]',
#                                                                   'separable_conv_2_bn_reduction_r
#                                                                  ight2_stem_1[0][0]']
#
#  reduction_left3_stem_1 (Averag  (None, 56, 56, 11)  0           ['reduction_pad_1_stem_1[0][0]']
#  ePooling2D)
#
#  separable_conv_2_bn_reduction_  (None, 56, 56, 11)  44          ['separable_conv_2_reduction_righ
#  right3_stem_1 (BatchNormalizat                                  t3_stem_1[0][0]']
#  ion)
#
#  reduction_left4_stem_1 (Averag  (None, 56, 56, 11)  0           ['reduction_add_1_stem_1[0][0]']
#  ePooling2D)
#
#  separable_conv_2_bn_reduction_  (None, 56, 56, 11)  44          ['separable_conv_2_reduction_left
#  left4_stem_1 (BatchNormalizati                                  4_stem_1[0][0]']
#  on)
#
#  reduction_right5_stem_1 (MaxPo  (None, 56, 56, 11)  0           ['reduction_pad_1_stem_1[0][0]']
#  oling2D)
#
#  zero_padding2d_4 (ZeroPadding2  (None, 112, 112, 32  0          ['adjust_relu_1_stem_2[0][0]']
#  D)                             )
#
#  reduction_add3_stem_1 (Add)    (None, 56, 56, 11)   0           ['reduction_left3_stem_1[0][0]',
#                                                                   'separable_conv_2_bn_reduction_r
#                                                                  ight3_stem_1[0][0]']
#  add_4 (Add)                    (None, 56, 56, 11)   0           ['reduction_add_2_stem_1[0][0]',
#                                                                   'reduction_left4_stem_1[0][0]']
#
#  reduction_add4_stem_1 (Add)    (None, 56, 56, 11)   0           ['separable_conv_2_bn_reduction_l
#                                                                  eft4_stem_1[0][0]',
#                                                                   'reduction_right5_stem_1[0][0]']
#
#  cropping2d_4 (Cropping2D)      (None, 111, 111, 32  0           ['zero_padding2d_4[0][0]']
#                                 )
#
#  reduction_concat_stem_1 (Conca  (None, 56, 56, 44)  0           ['reduction_add_2_stem_1[0][0]',
#  tenate)                                                          'reduction_add3_stem_1[0][0]',
#                                                                   'add_4[0][0]',
#                                                                   'reduction_add4_stem_1[0][0]']
#
#  adjust_avg_pool_1_stem_2 (Aver  (None, 56, 56, 32)  0           ['adjust_relu_1_stem_2[0][0]']
#  agePooling2D)
#
#  adjust_avg_pool_2_stem_2 (Aver  (None, 56, 56, 32)  0           ['cropping2d_4[0][0]']
#  agePooling2D)
#
#  activation_199 (Activation)    (None, 56, 56, 44)   0           ['reduction_concat_stem_1[0][0]']
#
#  adjust_conv_1_stem_2 (Conv2D)  (None, 56, 56, 11)   352         ['adjust_avg_pool_1_stem_2[0][0]'
#                                                                  ]
#
#  adjust_conv_2_stem_2 (Conv2D)  (None, 56, 56, 11)   352         ['adjust_avg_pool_2_stem_2[0][0]'
#                                                                  ]
#
#  reduction_conv_1_stem_2 (Conv2  (None, 56, 56, 22)  968         ['activation_199[0][0]']
#  D)
#
#  concatenate_4 (Concatenate)    (None, 56, 56, 22)   0           ['adjust_conv_1_stem_2[0][0]',
#                                                                   'adjust_conv_2_stem_2[0][0]']
#
#  reduction_bn_1_stem_2 (BatchNo  (None, 56, 56, 22)  88          ['reduction_conv_1_stem_2[0][0]']
#  rmalization)
#
#  adjust_bn_stem_2 (BatchNormali  (None, 56, 56, 22)  88          ['concatenate_4[0][0]']
#  zation)
#
#  activation_200 (Activation)    (None, 56, 56, 22)   0           ['reduction_bn_1_stem_2[0][0]']
#
#  activation_202 (Activation)    (None, 56, 56, 22)   0           ['adjust_bn_stem_2[0][0]']
#
#  separable_conv_1_pad_reduction  (None, 59, 59, 22)  0           ['activation_200[0][0]']
#  _left1_stem_2 (ZeroPadding2D)
#
#  separable_conv_1_pad_reduction  (None, 61, 61, 22)  0           ['activation_202[0][0]']
#  _right1_stem_2 (ZeroPadding2D)
#
#  separable_conv_1_reduction_lef  (None, 28, 28, 22)  1034        ['separable_conv_1_pad_reduction_
#  t1_stem_2 (SeparableConv2D)                                     left1_stem_2[0][0]']
#
#  separable_conv_1_reduction_rig  (None, 28, 28, 22)  1562        ['separable_conv_1_pad_reduction_
#  ht1_stem_2 (SeparableConv2D)                                    right1_stem_2[0][0]']
#
#  separable_conv_1_bn_reduction_  (None, 28, 28, 22)  88          ['separable_conv_1_reduction_left
#  left1_stem_2 (BatchNormalizati                                  1_stem_2[0][0]']
#  on)
#
#  separable_conv_1_bn_reduction_  (None, 28, 28, 22)  88          ['separable_conv_1_reduction_righ
#  right1_stem_2 (BatchNormalizat                                  t1_stem_2[0][0]']
#  ion)
#
#  activation_201 (Activation)    (None, 28, 28, 22)   0           ['separable_conv_1_bn_reduction_l
#                                                                  eft1_stem_2[0][0]']
#
#  activation_203 (Activation)    (None, 28, 28, 22)   0           ['separable_conv_1_bn_reduction_r
#                                                                  ight1_stem_2[0][0]']
#
#  separable_conv_2_reduction_lef  (None, 28, 28, 22)  1034        ['activation_201[0][0]']
#  t1_stem_2 (SeparableConv2D)
#
#  separable_conv_2_reduction_rig  (None, 28, 28, 22)  1562        ['activation_203[0][0]']
#  ht1_stem_2 (SeparableConv2D)
#
#  activation_204 (Activation)    (None, 56, 56, 22)   0           ['adjust_bn_stem_2[0][0]']
#
#  separable_conv_2_bn_reduction_  (None, 28, 28, 22)  88          ['separable_conv_2_reduction_left
#  left1_stem_2 (BatchNormalizati                                  1_stem_2[0][0]']
#  on)
#  separable_conv_2_bn_reduction_  (None, 28, 28, 22)  88          ['separable_conv_2_reduction_righ
#  right1_stem_2 (BatchNormalizat                                  t1_stem_2[0][0]']
#  ion)
#
#  separable_conv_1_pad_reduction  (None, 61, 61, 22)  0           ['activation_204[0][0]']
#  _right2_stem_2 (ZeroPadding2D)
#
#  activation_206 (Activation)    (None, 56, 56, 22)   0           ['adjust_bn_stem_2[0][0]']
#
#  reduction_add_1_stem_2 (Add)   (None, 28, 28, 22)   0           ['separable_conv_2_bn_reduction_l
#                                                                  eft1_stem_2[0][0]',
#                                                                   'separable_conv_2_bn_reduction_r
#                                                                  ight1_stem_2[0][0]']
#
#  separable_conv_1_reduction_rig  (None, 28, 28, 22)  1562        ['separable_conv_1_pad_reduction_
#  ht2_stem_2 (SeparableConv2D)                                    right2_stem_2[0][0]']
#
#  separable_conv_1_pad_reduction  (None, 59, 59, 22)  0           ['activation_206[0][0]']
#  _right3_stem_2 (ZeroPadding2D)
#
#  activation_208 (Activation)    (None, 28, 28, 22)   0           ['reduction_add_1_stem_2[0][0]']
#
#  separable_conv_1_bn_reduction_  (None, 28, 28, 22)  88          ['separable_conv_1_reduction_righ
#  right2_stem_2 (BatchNormalizat                                  t2_stem_2[0][0]']
#  ion)
#
#  separable_conv_1_reduction_rig  (None, 28, 28, 22)  1034        ['separable_conv_1_pad_reduction_
#  ht3_stem_2 (SeparableConv2D)                                    right3_stem_2[0][0]']
#
#  separable_conv_1_reduction_lef  (None, 28, 28, 22)  682         ['activation_208[0][0]']
#  t4_stem_2 (SeparableConv2D)
#
#  activation_205 (Activation)    (None, 28, 28, 22)   0           ['separable_conv_1_bn_reduction_r
#                                                                  ight2_stem_2[0][0]']
#
#  separable_conv_1_bn_reduction_  (None, 28, 28, 22)  88          ['separable_conv_1_reduction_righ
#  right3_stem_2 (BatchNormalizat                                  t3_stem_2[0][0]']
#  ion)
#
#  separable_conv_1_bn_reduction_  (None, 28, 28, 22)  88          ['separable_conv_1_reduction_left
#  left4_stem_2 (BatchNormalizati                                  4_stem_2[0][0]']
#  on)
#
#  reduction_pad_1_stem_2 (ZeroPa  (None, 57, 57, 22)  0           ['reduction_bn_1_stem_2[0][0]']
#  dding2D)
#
#  separable_conv_2_reduction_rig  (None, 28, 28, 22)  1562        ['activation_205[0][0]']
#  ht2_stem_2 (SeparableConv2D)
#
#  activation_207 (Activation)    (None, 28, 28, 22)   0           ['separable_conv_1_bn_reduction_r
#                                                                  ight3_stem_2[0][0]']
#
#  activation_209 (Activation)    (None, 28, 28, 22)   0           ['separable_conv_1_bn_reduction_l
#                                                                  eft4_stem_2[0][0]']
#
#  reduction_left2_stem_2 (MaxPoo  (None, 28, 28, 22)  0           ['reduction_pad_1_stem_2[0][0]']
#  ling2D)
#
#  separable_conv_2_bn_reduction_  (None, 28, 28, 22)  88          ['separable_conv_2_reduction_righ
#  right2_stem_2 (BatchNormalizat                                  t2_stem_2[0][0]']
#  ion)
#
#  separable_conv_2_reduction_rig  (None, 28, 28, 22)  1034        ['activation_207[0][0]']
#  ht3_stem_2 (SeparableConv2D)
#
#  separable_conv_2_reduction_lef  (None, 28, 28, 22)  682         ['activation_209[0][0]']
#  t4_stem_2 (SeparableConv2D)
#
#  adjust_relu_1_0 (Activation)   (None, 56, 56, 44)   0           ['reduction_concat_stem_1[0][0]']
#
#  reduction_add_2_stem_2 (Add)   (None, 28, 28, 22)   0           ['reduction_left2_stem_2[0][0]',
#                                                                   'separable_conv_2_bn_reduction_r
#                                                                  ight2_stem_2[0][0]']
#
#  reduction_left3_stem_2 (Averag  (None, 28, 28, 22)  0           ['reduction_pad_1_stem_2[0][0]']
#  ePooling2D)
#
#  separable_conv_2_bn_reduction_  (None, 28, 28, 22)  88          ['separable_conv_2_reduction_righ
#  right3_stem_2 (BatchNormalizat                                  t3_stem_2[0][0]']
#  ion)
#
#  reduction_left4_stem_2 (Averag  (None, 28, 28, 22)  0           ['reduction_add_1_stem_2[0][0]']
#  ePooling2D)
#
#  separable_conv_2_bn_reduction_  (None, 28, 28, 22)  88          ['separable_conv_2_reduction_left
#  left4_stem_2 (BatchNormalizati                                  4_stem_2[0][0]']
#  on)
#
#  reduction_right5_stem_2 (MaxPo  (None, 28, 28, 22)  0           ['reduction_pad_1_stem_2[0][0]']
#  oling2D)
#
#  zero_padding2d_5 (ZeroPadding2  (None, 57, 57, 44)  0           ['adjust_relu_1_0[0][0]']
#  D)
#
#  reduction_add3_stem_2 (Add)    (None, 28, 28, 22)   0           ['reduction_left3_stem_2[0][0]',
#                                                                   'separable_conv_2_bn_reduction_r
#                                                                  ight3_stem_2[0][0]']
#
#  add_5 (Add)                    (None, 28, 28, 22)   0           ['reduction_add_2_stem_2[0][0]',
#                                                                   'reduction_left4_stem_2[0][0]']
#
#  reduction_add4_stem_2 (Add)    (None, 28, 28, 22)   0           ['separable_conv_2_bn_reduction_l
#                                                                  eft4_stem_2[0][0]',
#                                                                   'reduction_right5_stem_2[0][0]']
#
#  cropping2d_5 (Cropping2D)      (None, 56, 56, 44)   0           ['zero_padding2d_5[0][0]']
#
#  reduction_concat_stem_2 (Conca  (None, 28, 28, 88)  0           ['reduction_add_2_stem_2[0][0]',
#  tenate)                                                          'reduction_add3_stem_2[0][0]',
#                                                                   'add_5[0][0]',
#                                                                   'reduction_add4_stem_2[0][0]']
#
#  adjust_avg_pool_1_0 (AveragePo  (None, 28, 28, 44)  0           ['adjust_relu_1_0[0][0]']
#  oling2D)
#
#  adjust_avg_pool_2_0 (AveragePo  (None, 28, 28, 44)  0           ['cropping2d_5[0][0]']
#  oling2D)
#
#  adjust_conv_1_0 (Conv2D)       (None, 28, 28, 22)   968         ['adjust_avg_pool_1_0[0][0]']
#
#  adjust_conv_2_0 (Conv2D)       (None, 28, 28, 22)   968         ['adjust_avg_pool_2_0[0][0]']
#
#  activation_210 (Activation)    (None, 28, 28, 88)   0           ['reduction_concat_stem_2[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 28, 28, 44)   0           ['adjust_conv_1_0[0][0]',
#                                                                   'adjust_conv_2_0[0][0]']
#
#  normal_conv_1_0 (Conv2D)       (None, 28, 28, 44)   3872        ['activation_210[0][0]']
#
#  adjust_bn_0 (BatchNormalizatio  (None, 28, 28, 44)  176         ['concatenate_5[0][0]']
#  n)
#
#  normal_bn_1_0 (BatchNormalizat  (None, 28, 28, 44)  176         ['normal_conv_1_0[0][0]']
#  ion)
#
#  activation_211 (Activation)    (None, 28, 28, 44)   0           ['normal_bn_1_0[0][0]']
#
#  activation_213 (Activation)    (None, 28, 28, 44)   0           ['adjust_bn_0[0][0]']
#
#  activation_215 (Activation)    (None, 28, 28, 44)   0           ['adjust_bn_0[0][0]']
#
#  activation_217 (Activation)    (None, 28, 28, 44)   0           ['adjust_bn_0[0][0]']
#
#  activation_219 (Activation)    (None, 28, 28, 44)   0           ['normal_bn_1_0[0][0]']
#
#  separable_conv_1_normal_left1_  (None, 28, 28, 44)  3036        ['activation_211[0][0]']
#  0 (SeparableConv2D)
#
#  separable_conv_1_normal_right1  (None, 28, 28, 44)  2332        ['activation_213[0][0]']
#  _0 (SeparableConv2D)
#
#  separable_conv_1_normal_left2_  (None, 28, 28, 44)  3036        ['activation_215[0][0]']
#  0 (SeparableConv2D)
#
#  separable_conv_1_normal_right2  (None, 28, 28, 44)  2332        ['activation_217[0][0]']
#  _0 (SeparableConv2D)
#
#  separable_conv_1_normal_left5_  (None, 28, 28, 44)  2332        ['activation_219[0][0]']
#  0 (SeparableConv2D)
#
#  separable_conv_1_bn_normal_lef  (None, 28, 28, 44)  176         ['separable_conv_1_normal_left1_0
#  t1_0 (BatchNormalization)                                       [0][0]']
#
#  separable_conv_1_bn_normal_rig  (None, 28, 28, 44)  176         ['separable_conv_1_normal_right1_
#  ht1_0 (BatchNormalization)                                      0[0][0]']
#  separable_conv_1_bn_normal_lef  (None, 28, 28, 44)  176         ['separable_conv_1_normal_left2_0
#  t2_0 (BatchNormalization)                                       [0][0]']
#
#  separable_conv_1_bn_normal_rig  (None, 28, 28, 44)  176         ['separable_conv_1_normal_right2_
#  ht2_0 (BatchNormalization)                                      0[0][0]']
#
#  separable_conv_1_bn_normal_lef  (None, 28, 28, 44)  176         ['separable_conv_1_normal_left5_0
#  t5_0 (BatchNormalization)                                       [0][0]']
#
#  activation_212 (Activation)    (None, 28, 28, 44)   0           ['separable_conv_1_bn_normal_left
#                                                                  1_0[0][0]']
#
#  activation_214 (Activation)    (None, 28, 28, 44)   0           ['separable_conv_1_bn_normal_righ
#                                                                  t1_0[0][0]']
#
#  activation_216 (Activation)    (None, 28, 28, 44)   0           ['separable_conv_1_bn_normal_left
#                                                                  2_0[0][0]']
#
#  activation_218 (Activation)    (None, 28, 28, 44)   0           ['separable_conv_1_bn_normal_righ
#                                                                  t2_0[0][0]']
#
#  activation_220 (Activation)    (None, 28, 28, 44)   0           ['separable_conv_1_bn_normal_left
#                                                                  5_0[0][0]']
#
#  separable_conv_2_normal_left1_  (None, 28, 28, 44)  3036        ['activation_212[0][0]']
#  0 (SeparableConv2D)
#
#  separable_conv_2_normal_right1  (None, 28, 28, 44)  2332        ['activation_214[0][0]']
#  _0 (SeparableConv2D)
#
#  separable_conv_2_normal_left2_  (None, 28, 28, 44)  3036        ['activation_216[0][0]']
#  0 (SeparableConv2D)
#
#  separable_conv_2_normal_right2  (None, 28, 28, 44)  2332        ['activation_218[0][0]']
#  _0 (SeparableConv2D)
#
#  separable_conv_2_normal_left5_  (None, 28, 28, 44)  2332        ['activation_220[0][0]']
#  0 (SeparableConv2D)
#
#  separable_conv_2_bn_normal_lef  (None, 28, 28, 44)  176         ['separable_conv_2_normal_left1_0
#  t1_0 (BatchNormalization)                                       [0][0]']
#
#  separable_conv_2_bn_normal_rig  (None, 28, 28, 44)  176         ['separable_conv_2_normal_right1_
#  ht1_0 (BatchNormalization)                                      0[0][0]']
#
#  separable_conv_2_bn_normal_lef  (None, 28, 28, 44)  176         ['separable_conv_2_normal_left2_0
#  t2_0 (BatchNormalization)                                       [0][0]']
#
#  separable_conv_2_bn_normal_rig  (None, 28, 28, 44)  176         ['separable_conv_2_normal_right2_
#  ht2_0 (BatchNormalization)                                      0[0][0]']
#
#  normal_left3_0 (AveragePooling  (None, 28, 28, 44)  0           ['normal_bn_1_0[0][0]']
#  2D)
#
#  normal_left4_0 (AveragePooling  (None, 28, 28, 44)  0           ['adjust_bn_0[0][0]']
#  2D)
#
#  normal_right4_0 (AveragePoolin  (None, 28, 28, 44)  0           ['adjust_bn_0[0][0]']
#  g2D)
#
#  separable_conv_2_bn_normal_lef  (None, 28, 28, 44)  176         ['separable_conv_2_normal_left5_0
#  t5_0 (BatchNormalization)                                       [0][0]']
#
#  normal_add_1_0 (Add)           (None, 28, 28, 44)   0           ['separable_conv_2_bn_normal_left
#                                                                  1_0[0][0]',
#                                                                   'separable_conv_2_bn_normal_righ
#                                                                  t1_0[0][0]']
#
#  normal_add_2_0 (Add)           (None, 28, 28, 44)   0           ['separable_conv_2_bn_normal_left
#                                                                  2_0[0][0]',
#                                                                   'separable_conv_2_bn_normal_righ
#                                                                  t2_0[0][0]']
#
#  normal_add_3_0 (Add)           (None, 28, 28, 44)   0           ['normal_left3_0[0][0]',
#                                                                   'adjust_bn_0[0][0]']
# ...
#                                                                   'normal_right4_11[0][0]']
#
#  normal_add_5_11 (Add)          (None, 7, 7, 176)    0           ['separable_conv_2_bn_normal_left
#                                                                  5_11[0][0]',
#                                                                   'normal_bn_1_11[0][0]']
#
#  normal_concat_11 (Concatenate)  (None, 7, 7, 1056)  0           ['adjust_bn_11[0][0]',
#                                                                   'normal_add_1_11[0][0]',
#                                                                   'normal_add_2_11[0][0]',
#                                                                   'normal_add_3_11[0][0]',
#                                                                   'normal_add_4_11[0][0]',
#                                                                   'normal_add_5_11[0][0]']
#
#  activation_363 (Activation)    (None, 7, 7, 1056)   0           ['normal_concat_10[0][0]']
#  activation_364 (Activation)    (None, 7, 7, 1056)   0           ['normal_concat_11[0][0]']
#
#  adjust_conv_projection_12 (Con  (None, 7, 7, 176)   185856      ['activation_363[0][0]']
#  v2D)
#
#  normal_conv_1_12 (Conv2D)      (None, 7, 7, 176)    185856      ['activation_364[0][0]']
#
#  adjust_bn_12 (BatchNormalizati  (None, 7, 7, 176)   704         ['adjust_conv_projection_12[0][0]
#  on)                                                             ']
#
#  normal_bn_1_12 (BatchNormaliza  (None, 7, 7, 176)   704         ['normal_conv_1_12[0][0]']
#  tion)
#
#  activation_365 (Activation)    (None, 7, 7, 176)    0           ['normal_bn_1_12[0][0]']
#
#  activation_367 (Activation)    (None, 7, 7, 176)    0           ['adjust_bn_12[0][0]']
#
#  activation_369 (Activation)    (None, 7, 7, 176)    0           ['adjust_bn_12[0][0]']
#
#  activation_371 (Activation)    (None, 7, 7, 176)    0           ['adjust_bn_12[0][0]']
#
#  activation_373 (Activation)    (None, 7, 7, 176)    0           ['normal_bn_1_12[0][0]']
#
#  separable_conv_1_normal_left1_  (None, 7, 7, 176)   35376       ['activation_365[0][0]']
#  12 (SeparableConv2D)
#
#  separable_conv_1_normal_right1  (None, 7, 7, 176)   32560       ['activation_367[0][0]']
#  _12 (SeparableConv2D)
#
#  separable_conv_1_normal_left2_  (None, 7, 7, 176)   35376       ['activation_369[0][0]']
#  12 (SeparableConv2D)
#
#  separable_conv_1_normal_right2  (None, 7, 7, 176)   32560       ['activation_371[0][0]']
#  _12 (SeparableConv2D)
#
#  separable_conv_1_normal_left5_  (None, 7, 7, 176)   32560       ['activation_373[0][0]']
#  12 (SeparableConv2D)
#
#  separable_conv_1_bn_normal_lef  (None, 7, 7, 176)   704         ['separable_conv_1_normal_left1_1
#  t1_12 (BatchNormalization)                                      2[0][0]']
#
#  separable_conv_1_bn_normal_rig  (None, 7, 7, 176)   704         ['separable_conv_1_normal_right1_
#  ht1_12 (BatchNormalization)                                     12[0][0]']
#
#  separable_conv_1_bn_normal_lef  (None, 7, 7, 176)   704         ['separable_conv_1_normal_left2_1
#  t2_12 (BatchNormalization)                                      2[0][0]']
#
#  separable_conv_1_bn_normal_rig  (None, 7, 7, 176)   704         ['separable_conv_1_normal_right2_
#  ht2_12 (BatchNormalization)                                     12[0][0]']
#
#  separable_conv_1_bn_normal_lef  (None, 7, 7, 176)   704         ['separable_conv_1_normal_left5_1
#  t5_12 (BatchNormalization)                                      2[0][0]']
#
#  activation_366 (Activation)    (None, 7, 7, 176)    0           ['separable_conv_1_bn_normal_left
#                                                                  1_12[0][0]']
#
#  activation_368 (Activation)    (None, 7, 7, 176)    0           ['separable_conv_1_bn_normal_righ
#                                                                  t1_12[0][0]']
#
#  activation_370 (Activation)    (None, 7, 7, 176)    0           ['separable_conv_1_bn_normal_left
#                                                                  2_12[0][0]']
#
#  activation_372 (Activation)    (None, 7, 7, 176)    0           ['separable_conv_1_bn_normal_righ
#                                                                  t2_12[0][0]']
#
#  activation_374 (Activation)    (None, 7, 7, 176)    0           ['separable_conv_1_bn_normal_left
#                                                                  5_12[0][0]']
#
#  separable_conv_2_normal_left1_  (None, 7, 7, 176)   35376       ['activation_366[0][0]']
#  12 (SeparableConv2D)
#
#  separable_conv_2_normal_right1  (None, 7, 7, 176)   32560       ['activation_368[0][0]']
#  _12 (SeparableConv2D)
#
#  separable_conv_2_normal_left2_  (None, 7, 7, 176)   35376       ['activation_370[0][0]']
#  12 (SeparableConv2D)
#
#  separable_conv_2_normal_right2  (None, 7, 7, 176)   32560       ['activation_372[0][0]']
#  _12 (SeparableConv2D)
#
#  separable_conv_2_normal_left5_  (None, 7, 7, 176)   32560       ['activation_374[0][0]']
#  12 (SeparableConv2D)
#  separable_conv_2_bn_normal_lef  (None, 7, 7, 176)   704         ['separable_conv_2_normal_left1_1
#  t1_12 (BatchNormalization)                                      2[0][0]']
#
#  separable_conv_2_bn_normal_rig  (None, 7, 7, 176)   704         ['separable_conv_2_normal_right1_
#  ht1_12 (BatchNormalization)                                     12[0][0]']
#
#  separable_conv_2_bn_normal_lef  (None, 7, 7, 176)   704         ['separable_conv_2_normal_left2_1
#  t2_12 (BatchNormalization)                                      2[0][0]']
#
#  separable_conv_2_bn_normal_rig  (None, 7, 7, 176)   704         ['separable_conv_2_normal_right2_
#  ht2_12 (BatchNormalization)                                     12[0][0]']
#
#  normal_left3_12 (AveragePoolin  (None, 7, 7, 176)   0           ['normal_bn_1_12[0][0]']
#  g2D)
#
#  normal_left4_12 (AveragePoolin  (None, 7, 7, 176)   0           ['adjust_bn_12[0][0]']
#  g2D)
#
#  normal_right4_12 (AveragePooli  (None, 7, 7, 176)   0           ['adjust_bn_12[0][0]']
#  ng2D)
#
#  separable_conv_2_bn_normal_lef  (None, 7, 7, 176)   704         ['separable_conv_2_normal_left5_1
#  t5_12 (BatchNormalization)                                      2[0][0]']
#
#  normal_add_1_12 (Add)          (None, 7, 7, 176)    0           ['separable_conv_2_bn_normal_left
#                                                                  1_12[0][0]',
#                                                                   'separable_conv_2_bn_normal_righ
#                                                                  t1_12[0][0]']
#
#  normal_add_2_12 (Add)          (None, 7, 7, 176)    0           ['separable_conv_2_bn_normal_left
#                                                                  2_12[0][0]',
#                                                                   'separable_conv_2_bn_normal_righ
#                                                                  t2_12[0][0]']
#
#  normal_add_3_12 (Add)          (None, 7, 7, 176)    0           ['normal_left3_12[0][0]',
#                                                                   'adjust_bn_12[0][0]']
#
#  normal_add_4_12 (Add)          (None, 7, 7, 176)    0           ['normal_left4_12[0][0]',
#                                                                   'normal_right4_12[0][0]']
#
#  normal_add_5_12 (Add)          (None, 7, 7, 176)    0           ['separable_conv_2_bn_normal_left
#                                                                  5_12[0][0]',
#                                                                   'normal_bn_1_12[0][0]']
#
#  normal_concat_12 (Concatenate)  (None, 7, 7, 1056)  0           ['adjust_bn_12[0][0]',
#                                                                   'normal_add_1_12[0][0]',
#                                                                   'normal_add_2_12[0][0]',
#                                                                   'normal_add_3_12[0][0]',
#                                                                   'normal_add_4_12[0][0]',
#                                                                   'normal_add_5_12[0][0]']
#
#  activation_375 (Activation)    (None, 7, 7, 1056)   0           ['normal_concat_12[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 1056)        0           ['activation_375[0][0]']
#  obalAveragePooling2D)
#
#  dense_2 (Dense)                (None, 512)          541184      ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dropout_1 (Dropout)            (None, 512)          0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 8)            4104        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 4,815,004
# Trainable params: 545,640
# Non-trainable params: 4,269,364
# __________________________________________________________________________________________________

# %%
batch_size=32

# %%
base_model = tf.keras.applications.NASNetMobile(
    input_shape=(224, 224, 3),
    include_top=False)

# Freeze all but the last few layers of the base model
for layer in base_model.layers[:-10]:
    layer.trainable = False

# Add some layers on top of the pre-trained model
x = base_model.output
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dense(512, activation='relu')(x)
x = tf.keras.layers.Dropout(0.5)(x)
x = tf.keras.layers.Dense(8, activation='softmax')(x)

# Create the final model
model = tf.keras.models.Model(inputs=base_model.input, outputs=x)

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(lr=1e-4),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model with data augmentation and early stopping
history = model.fit(
    train_data,
    steps_per_epoch=train_data.n// batch_size,
    epochs=50,
    validation_steps=val_data.n// batch_size,
    validation_data=val_data)
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1
# 22/22 [==============================] - 272s 12s/step - loss: 0.3934 - accuracy: 0.8424 - val_loss: 1.0111 - val_accuracy: 0.6562
# Epoch 42/50
# 22/22 [==============================] - 276s 13s/step - loss: 0.3915 - accuracy: 0.8601 - val_loss: 0.8403 - val_accuracy: 0.6625
# Epoch 43/50
# 22/22 [==============================] - 264s 12s/step - loss: 0.3760 - accuracy: 0.8586 - val_loss: 0.7961 - val_accuracy: 0.6562
# Epoch 44/50
# 22/22 [==============================] - 259s 12s/step - loss: 0.3749 - accuracy: 0.8586 - val_loss: 0.8076 - val_accuracy: 0.7375
# Epoch 45/50
# 22/22 [==============================] - 273s 13s/step - loss: 0.3643 - accuracy: 0.8513 - val_loss: 0.8207 - val_accuracy: 0.6750
# Epoch 46/50
# 22/22 [==============================] - 251s 11s/step - loss: 0.3239 - accuracy: 0.8778 - val_loss: 0.7585 - val_accuracy: 0.7000
# Epoch 47/50
# 22/22 [==============================] - 261s 12s/step - loss: 0.3378 - accuracy: 0.8748 - val_loss: 0.7342 - val_accuracy: 0.7437
# Epoch 48/50
# 22/22 [==============================] - 254s 12s/step - loss: 0.3582 - accuracy: 0.8733 - val_loss: 0.8236 - val_accuracy: 0.7188
# Epoch 49/50
# 22/22 [==============================] - 277s 13s/step - loss: 0.3802 - accuracy: 0.8542 - val_loss: 0.7364 - val_accuracy: 0.7312
# Epoch 50/50
# 22/22 [==============================] - 265s 12s/step - loss: 0.3335 - accuracy: 0.8660 - val_loss: 0.9542 - val_accuracy: 0.6250

# %%
# Evaluate the model on the validation dataset
loss, accuracy = model.evaluate(val_data)
print(f'Validation Loss: {loss:.4f}')
print(f'Validation Accuracy: {accuracy:.4f}')
# Out:
# 6/6 [==============================] - 57s 9s/step - loss: 0.8438 - accuracy: 0.6667
# Validation Loss: 0.8438
# Validation Accuracy: 0.6667

# %%
import matplotlib.pyplot as plt

def plot_loss(history):
    # Plot training and validation loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'val'], loc='upper right')
    plt.show()

def plot_accuracy(history):
    # Plot training and validation accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'val'], loc='lower right')
    plt.show()

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.6)

test_data = datagen.flow_from_directory(
    data_dir,
    target_size=(224, 224),
    batch_size= 32,
    shuffle=True,
    class_mode='categorical',
    subset='validation')
# Out:
# Found 528 images belonging to 8 classes.

# %%
# Evaluate the model on the test set
loss, accuracy = model.evaluate(test_data)

# Print the results
print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
# Out:
# 17/17 [==============================] - 151s 9s/step - loss: 0.5130 - accuracy: 0.8011
# Test Loss: 0.5129782557487488
# Test Accuracy: 0.8011363744735718

# %%
# Get the true labels for the test data
true_labels = test_data.classes

# Get the predicted labels for the test data
predicted_labels = model.predict(test_data)
predicted_labels = np.argmax(predicted_labels, axis=1)
# Out:
# 17/17 [==============================] - 91s 5s/step

# %%
# Generate the classification report
print(classification_report(true_labels, predicted_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.18      0.20      0.19        60
#            1       0.17      0.13      0.15        67
#            2       0.14      0.10      0.12        60
#            3       0.12      0.10      0.11        67
#            4       0.11      0.12      0.11        60
#            5       0.11      0.11      0.11        44
#            6       0.20      0.19      0.19        85
#            7       0.14      0.19      0.16        85
#
#     accuracy                           0.15       528
#    macro avg       0.14      0.14      0.14       528
# weighted avg       0.15      0.15      0.15       528

# %%
plot_loss(history)
plot_accuracy(history)

# %%
# Get the true labels for the test data
true_labels = test_data.classes

# Get the predicted labels for the test data
predicted_labels = model.predict(test_data)
predicted_labels = np.argmax(predicted_labels, axis=1)
# Out:
# 17/17 [==============================] - 60s 3s/step

# %%
# Generate the classification report
print(classification_report(true_labels, predicted_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.14      0.15      0.14        60
#            1       0.08      0.07      0.08        67
#            2       0.10      0.08      0.09        60
#            3       0.11      0.10      0.11        67
#            4       0.20      0.22      0.21        60
#            5       0.02      0.02      0.02        44
#            6       0.17      0.14      0.15        85
#            7       0.21      0.27      0.24        85
#
#     accuracy                           0.14       528
#    macro avg       0.13      0.13      0.13       528
# weighted avg       0.14      0.14      0.14       528

# %%
# Generate the confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[ 9  7  5  8  6  5 13  7]
#  [12  5  8  7 10  5  6 14]
#  [ 7  6  5  9  7  2  9 15]
#  [ 5 10  7  7  8  8  7 15]
#  [ 8 10  2  5 13  4  8 10]
#  [ 9  4  6  7  3  1  6  8]
#  [ 7  9  8  9  9 13 12 18]
#  [ 8  9 10 12  8  4 11 23]]

# %%
# Get the true labels for the test data
true_labels = test_data.classes

# %%
#Get the predicted labels for the test data
predicted_labels = model.predict(test_data)
predicted_labels = np.argmax(predicted_labels, axis=1)
# Out:
# 17/17 [==============================] - 51s 3s/step

# %%
# Generate the classification report
print(classification_report(true_labels, predicted_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.12      0.13      0.13        60
#            1       0.18      0.15      0.16        67
#            2       0.10      0.08      0.09        60
#            3       0.09      0.09      0.09        67
#            4       0.09      0.10      0.10        60
#            5       0.11      0.11      0.11        44
#            6       0.14      0.12      0.13        85
#            7       0.19      0.25      0.21        85
#
#     accuracy                           0.13       528
#    macro avg       0.13      0.13      0.13       528
# weighted avg       0.13      0.13      0.13       528

# %%
# Generate the confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[ 8  7  7  6  9  1 10 12]
#  [ 9 10  6  9  8  9  7  9]
#  [ 8  7  5  4  9  5 10 12]
#  [10  7  4  6 11  5  9 15]
#  [ 7  6  8  9  6  5  6 13]
#  [ 5  4  4  6  4  5  7  9]
#  [ 9 12 10 10  6  8 10 20]
#  [ 9  4  4 15 13  7 12 21]]

# %%
import matplotlib.pyplot as plt

# %%
# Get a few images from the test set
num_images = 5
test_images, test_labels = next(test_data)

# %%
# Make predictions on the test images
predictions = model.predict(test_images)
predicted_labels = np.argmax(predictions, axis=1)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
# Convert one-hot encoded labels to class names
class_names = list(test_data.class_indices.keys())
true_labels = np.argmax(test_labels, axis=1)
true_class_names = [class_names[label] for label in true_labels]
predicted_class_names = [class_names[label] for label in predicted_labels]

# %%
# Plot the images with their predicted and true labels
fig, axes = plt.subplots(1, num_images, figsize=(20, 5))

for i, ax in enumerate(axes):
    ax.imshow(test_images[i])
    ax.axis('off')
    ax.set_title(f"Predicted: {predicted_class_names[i]}\nTrue: {true_class_names[i]}")

plt.show()

# %%
model.save("D:\\Msc GU\\Msc 4th Sem\\Thesis\\nasnet.h5")
